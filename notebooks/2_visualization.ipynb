# %%
from benchmark.file import read_csv
import seaborn as sns
from os import PathLike, chdir
from pathlib import Path
from benchmark.api import Api, ApiBefore, ApiAfter
from time import sleep

if not "PROJECT_DIR" in globals():
    PROJECT_DIR = Path().resolve().parent
    chdir(PROJECT_DIR)


def out(name: str) -> PathLike:
    return PROJECT_DIR / "out" / f"{name}.csv"

# %% [markdown]
# ## Compose Benchmarks

# %%
states = ["before", "after", "queue"]

# %% [markdown]
# ### Cold Start

# %%
files = [out(f"cold-start_{state}") for state in states]
sns.barplot(data=read_csv(files), x="type", y="duration")
# Out:
# <Axes: xlabel='type', ylabel='duration'>

# %% [markdown]
# ### Warm Start

# %%
files = [out(f"warm-start_{state}") for state in states]
sns.barplot(data=read_csv(files), x="type", y="duration")
# Out:
# <Axes: xlabel='type', ylabel='duration'>

# %% [markdown]
# ### Stop

# %%
files = [out(f"stop_{state}") for state in states]
sns.barplot(data=read_csv(files), x="type", y="duration")
# Out:
# <Axes: xlabel='type', ylabel='duration'>

# %% [markdown]
# ### Remove

# %%
files = [out(f"remove_{state}") for state in states]
sns.barplot(data=read_csv(files), x="type", y="duration")
# Out:
# <Axes: xlabel='type', ylabel='duration'>

# %% [markdown]
# ## API

# %% [markdown]
# ### Create Database

# %%
files = [out(f"create-database_{state}") for state in states[:-1]]
sns.barplot(data=read_csv(files), x="type", y="duration")
# Out:
# <Axes: xlabel='type', ylabel='duration'>

# %% [markdown]
# ### Create Table

# %%
files = [out(f"create-table_{state}") for state in states[:-1]]
sns.barplot(data=read_csv(files), x="type", y="duration")
# Out:
# <Axes: xlabel='type', ylabel='duration'>

# %% [markdown]
# ### Create Query

# %%
files = [out(f"create-query_{state}") for state in states[:-1]]
sns.barplot(data=read_csv(files), x="type", y="duration")
# Out:
# <Axes: xlabel='type', ylabel='duration'>

# %% [markdown]
# ### Re-Execute Query

# %%
files = [out(f"execute-query_{state}") for state in states[:-1]]
sns.barplot(data=read_csv(files), x="type", y="duration")
# Out:
# <Axes: xlabel='type', ylabel='duration'>

# %% [markdown]
# ### Insert Row

# %%
files = [out(f"insert-row_{state}") for state in states[:-1]]
sns.barplot(data=read_csv(files), x="type", y="duration")
# Out:
# <Axes: xlabel='type', ylabel='duration'>

# %% [markdown]
# ### Update Row

# %%
files = [out(f"update-row_{state}") for state in states[:-1]]
sns.barplot(data=read_csv(files), x="type", y="duration")
# Out:
# <Axes: xlabel='type', ylabel='duration'>

# %% [markdown]
# ### Delete Row

# %%
files = [out(f"delete-row_{state}") for state in states[:-1]]
sns.barplot(data=read_csv(files), x="type", y="duration")
# Out:
# <Axes: xlabel='type', ylabel='duration'>

# %% [markdown]
# ### Import CSV

# %%
files = [out(f"import-csv_{state}") for state in states[:-1]]
sns.barplot(data=read_csv(files), x="type", y="duration")
# Out:
# <Axes: xlabel='type', ylabel='duration'>
